# %%
import plotly.graph_objects as go
import dash
import numpy as np
import pandas as pd

import plotly.offline as pyo
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import State, Input, Output

# %%
import os
os.getcwd()
# Out:
# '/Users/seiryu8808/Desktop/UWinsc/Github/UnacquiredSites/src/modules/dashboard'

# %%
df = pd.read_csv('/Users/seiryu8808/Desktop/UWinsc/Github/UnacquiredSites/src/output/for_model/comparison_file.tsv', sep='\t')

# %%
df
# Out:
#        prediction_proba  predicted_label  original_label  \
# 0              0.000718                0               0
# 1              0.000718                0               0
# 2              0.000718                0               0
# 3              0.000718                0               0
# 4              0.000718                0               0
# ...                 ...              ...             ...
# 21323          0.000718                0               0
# 21324          0.000718                0               0
# 21325          0.000718                0               0
# 21326          0.000718                0               0
# 21327          0.000718                0               0
#
#                          _gddid  sentid  \
# 0      54b43268e138239d8684f736     237
# 1      5754e288cf58f1b0c7844cc3     114
# 2      570cfa0bcf58f189c8b28746     422
# 3      580bf303cf58f1668e5f35af     262
# 4      578b7346cf58f15ebd0adbc1      36
# ...                         ...     ...
# 21323  54b4326ae138239d8684fb60     113
# 21324  5505e0f9e1382326932d8ef7     335
# 21325  578b5aabcf58f1587003efba     633
# 21326  5505877fe1382326932d8d76     892
# 21327  54b43269e138239d8684f8ec     160
#
#                                                 sentence found_lat  \
# 0                                     S. neglectus Csy .        []
# 1      RS and GIS The forested steep slopes of the Ac...        []
# 2                                        Hill, C.L1998 .        []
# 3      Occurrence and abundance of 6-methyl branched ...        []
# 4                                               J. Bot .        []
# ...                                                  ...       ...
# 21323                                              4.2 .        []
# 21324  Thus, after approximately 1.5 ka BP, the occur...        []
# 21325                         Plant inertia reassessed .        []
# 21326                              Troels-Smith, J1955 .        []
# 21327  Portions of dung were removed from the interio...        []
#
#            latnorth found_long        longeast               found_sites
# 0            ['43']         []          ['80']                        []
# 1            ['16']         []          ['78']  ['potapuram', 'cheruvu']
# 2      ['48', '45']         []  ['112', '110']                        []
# 3            ['67']         []         ['172']                        []
# 4            ['47']         []          ['93']                        []
# ...             ...        ...             ...                       ...
# 21323        ['41']         []          ['24']                        []
# 21324  ['52', '54']         []    ['71', '67']                        []
# 21325        ['44']         []          ['80']                        []
# 21326        ['62']         []          ['10']                        []
# 21327        ['32']         []         ['106']                        []
#
# [21328 rows x 11 columns]

# %%
def datagen():

    Base_Data = pd.read_csv('/Users/seiryu8808/Desktop/UWinsc/Github/UnacquiredSites/src/output/for_model/comparison_file.tsv', sep='\t')
    
    return(Base_Data)

# %%
gddid_list = list(df['_gddid'].unique())

options_list = []
for i in gddid_list:
    options_list.append({'label':i, 'value':i})

# %%
sentid_list = list(df['sentid'].unique())
list.sort(sentid_list)

sent_opt_list = []
for i in sentid_list:
    sent_opt_list.append({'label':i, 'value':i})

# %%
def fig_generator(sample_data):
    sample_data = sample_data.reset_index(drop=True)
    plot_data = go.Scatter(x = sample_data['sentid'], y = sample_data['prediction_proba'], name = 'proba of sentence')
    plot_layout = go.Layout()
    
    fig = go.Figure(data = plot_data, layout = plot_layout)
    
    return(fig.data, fig.layout)

# %%
### Dash board code 
    
app = dash.Dash()

### defining the HTML component


app.layout = html.Div(children=[html.Div("ML Record Mining",style= {   "color": "white",
                                                      "text-align": "center","background-color": "blue",
                                                      "border-style": "dotted","display":"inline-block","width":"80%"
                                                      
                                                    }),
                       html.Div(dcc.Dropdown(id = "drop_down_1" ,options= options_list , value= '54b43268e138239d8684f736'
                                                       ),style= {
                                                      "color": "green",
                                                      "text-align": "center","background-color": "darkorange",
                                                      "border-style": "dotted","display":"inline-block","width":"20%"
                                                      
                                                    }),
                       html.Div(dcc.Dropdown(id = "drop_down_2" ,options= sent_opt_list , value= '3'
                                                       ),style= {
                                                      "color": "green",
                                                      "text-align": "center","background-color": "darkorange",
                                                      "border-style": "dotted","display":"inline-block","width":"20%"
                                                      
                                                    }),
                                
                       html.Div(children=[html.P(
                            id="map-title",
                            children = "Probability of being a sentence ",
                        ), html.Div(dcc.Graph(id ="plot_area"))
                                                       ],style= {
                                                      "color": "black",
                                                      "text-align": "center","background-color": "yellow",
                                                      "border-style": "dotted","display":"inline-block","width":"75%",
                                                      "height":"450px"
                                                                                                            
                                                    }),
                        html.Div("Prev Sent, Curr Sent, Nxt Sent", style = {"color":"black",
                                                                                     "display":"inline-block", 
                                                                                     "width":"100%", "height":"200px"}
                                ),
                        html.Div("Control Bottons", style = {"color":"black", 
                                                                      "display":"inline-block", "width":"100%",
                                                                      "height":"70px"})],
                      style={"width":"100%",'paffing':10})

## Creating callback buttons

@app.callback(Output("plot_area", 'figure'),
              
              [Input("drop_down_1", "value")])

def updateplot(input_cat):
    
    df= datagen()
    sample_data = df[df["_gddid"] == input_cat ]
    
    trace,layout = fig_generator(sample_data)
    
    return {
        'data': trace,
        'layout':layout
    }
    
    
    
if __name__=='__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  Warning: This is a development server. Do not use app.run_server
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  in production, use a production WSGI server like gunicorn instead.
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Jul/2020 18:46:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:46:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:46:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:46:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:47:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:47:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:47:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:48:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jul/2020 18:48:52] "POST /_dash-update-component HTTP/1.1" 200 -
